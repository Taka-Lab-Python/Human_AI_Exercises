# %%
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
# !pip install japanize-matplotlib
import japanize_matplotlib

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# 混同行列　（Confusion matrix）を作成するコード

# %%
##
# 混同行列の作成
# 学習済みモデルを使う
#

# 1. テストデータに対する予測
y_pred_proba = model.predict(X_test)

# 2. 確率が最も高いインデックス（0〜9の数字）を予測結果とする
y_pred = np.argmax(y_pred_proba, axis=1)

# One-hot形式の正解ラベル（y_test）を、元の数値（0〜9）に戻す
y_true = np.argmax(y_test, axis=1)

# 3. 混同行列の計算（Scikit-learnの関数を使用）
cm = confusion_matrix(y_true, y_pred)

# 4. Seabornのheatmapを使った美しい可視化
plt.figure(figsize=(10, 8))
sns.heatmap(
    cm,
    annot=True,       # 各セルの中に実際の数値を表示する
    fmt='d',          # 数値を「整数（Integer）」として表示する（指数表記を防ぐ）
    cmap='Blues',     # 配色のテーマを「青系」にする
    cbar=True,        # 横にあるカラーバーを表示する
    xticklabels=range(10),  # X軸のラベル（予測値：0〜9）
    yticklabels=range(10)   # Y軸のラベル（正解値：0〜9）
)

plt.title('混同行列 (MNIST Classification)', fontsize=14)
plt.ylabel('正解 (True)', fontsize=12)
plt.xlabel('kerasの予測', fontsize=12)
plt.show()
