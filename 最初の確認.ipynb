# %%
import sys
import tensorflow as tf

# ① Pythonバージョンの確認
print(f"【1】Python環境: OK (Version {sys.version.split()[0]})")

# ② TensorFlowの確認
print(f"【2】TensorFlow: OK (Version {tf.__version__})")

# ③ 実行できるかの確認
print("Pythonが正常に動いています！")
